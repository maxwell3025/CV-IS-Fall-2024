# %% [markdown]
# # DCGAN

# %%
from functions import train
train()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import functions
#
# File ~/Repositories/CV-IS-Fall-2024/pytorch-quickstart/maxwell/functions.py:163
#     161 generator_error = criterion(output, label)
#     162 generator_error.backward()
# --> 163 generator_avg = output.mean().item()
#     164 generator_optimizer.step()
#     165 #endregion
#
# File ~/.local/lib/python3.10/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# ...
