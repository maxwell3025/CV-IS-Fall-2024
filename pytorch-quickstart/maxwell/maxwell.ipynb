# %% [markdown]
# # DCGAN

# %%
from functions import train
train()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 from functions import train
# ----> 2 train()
#
# File ~/Repositories/CV-IS-Fall-2024/pytorch-quickstart/maxwell/functions.py:162, in train()
#     159 generator_optimizer.step()
#     160 #endregion
# --> 162 print('[%d/%d][%d/%d]\tLoss_D: %.4f\tLoss_G: %.4f\tD(x): %.4f\tD(G(z)): %.4f / %.4f'
#     163     % (
#     164         epoch, 1,
#     165         i, len(dataloader),
#     166         discriminator_error.item(),
#     167         generator_error.item(),
#     168         discriminator_real_avg,
#     169         discriminator_fake_avg, generator_avg
#     170     )
#     171 )
#     173 #Check how the generator is doing by saving G's output on fixed_noise
#     174 with torch.no_grad():
#
# ...
