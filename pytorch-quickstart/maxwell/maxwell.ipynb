# %% [markdown]
# # DCGAN

# %%
from functions import train
train()
# Out:
# [0/1][0/1583]	Loss_D: 1.5271	Loss_G: 2.8035	D(x): 0.5491	D(G(z)): 0.5931 / 0.0639
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 from functions import train
# ----> 2 train()
#
# File ~/Repositories/CV-IS-Fall-2024/pytorch-quickstart/maxwell/functions.py:180, in train()
#     178 #Check how the generator is doing by saving G's output on fixed_noise
#     179 with torch.no_grad():
# --> 180     fake = generator_network(fixed_noise).detach().cpu()
#     181     composite_image = numpy.transpose(
#     182         torchvision.utils.make_grid(
#     183             fake.to(device)[:64],
#    (...)
#     187         (1, 2, 0)
#     188     )
#     189     display.clear_output(wait=True)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
# ...
