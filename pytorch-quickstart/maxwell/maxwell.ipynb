# %% [markdown]
# # DCGAN

# %%
from functions import train
train()
# Out:
# {'image': tensor([[[[-0.9843, -0.9922, -0.9373,  ...,  0.7569,  0.8588,  0.8824],
#           [-0.9922, -0.9765, -0.7490,  ...,  0.7569,  0.8196,  0.8510],
#           [-0.9765, -0.8196, -0.4196,  ...,  0.7647,  0.7961,  0.8118],
#           ...,
#           [ 0.6392,  0.6471,  0.6706,  ..., -0.0039, -0.2549, -0.4118],
#           [ 0.6549,  0.6627,  0.6706,  ...,  0.0745, -0.2235, -0.4118],
#           [ 0.6627,  0.6627,  0.6627,  ...,  0.0745, -0.1216, -0.2157]],
#
#          [[-1.0000, -1.0000, -0.9529,  ...,  0.6706,  0.7725,  0.7961],
#           [-1.0000, -0.9765, -0.7490,  ...,  0.6706,  0.7333,  0.7647],
#           [-0.9686, -0.8118, -0.4196,  ...,  0.6784,  0.7098,  0.7255],
#           ...,
#           [ 0.1529,  0.1529,  0.1686,  ..., -0.2000, -0.4902, -0.6392],
#           [ 0.1843,  0.1922,  0.2157,  ..., -0.1922, -0.4667, -0.6235],
#           [ 0.1922,  0.1922,  0.2000,  ..., -0.3412, -0.4588, -0.4745]],
#
# ...
